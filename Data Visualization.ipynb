# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt


df_all = pd.read_pickle('pickled_df_ALL.pk')

# %%
import datetime


df_all.keys()

ma, mi = math.floor(df_all['SCam3_tt'].max()), math.floor(df_all['SCam3_tt'].min())


datetime.timedelta(seconds=(ma - mi))
# df_all['SCam3_tt'] = df_all['SCam3_tt'].astype(float).map(math.floor)

# df_all['SCam3_tt'].map(str).map(lambda x: datetime.strptime(x, '%S')).head()


#remove tt keys and set index to tt 

# import math
# from dateutil import parser

# scam_pre_bin = scam_pre_bin['SCam3_tt']

# print(scam_pre_bin.head())

# scam_pre_bin.set_index(scam_pre_bin['SCam3_tt'].map(parser.parse), inplace=True)

# # Taking mean values for a frequency of 2 minutes
# scam_pre_bin.groupby(pd.TimeGrouper('10S')).head()
# df_group = scam_pre_bin.groupby(pd.Grouper(level='Time', freq='D'))['SCam3_tt'].agg('mean')   
# df_group.dropna(inpla5ce=True)
# df_group = df_group.to_frame().reset_index()
# print(df_group)



# sns.heatmap(df_cam_ctr[:10000], annot=True)
# plt.show()
# Out:
# datetime.timedelta(seconds=12308)

# %%
#this excludes gaussian sum

df_cam_ctr = df_all[['SCam3_Gauss_xCentroid',  'SCam3_Gauss_yCentroid','SCam3_Gauss_uCentroid','SCam3_Gauss_vCentroid']]

df_cam_var = df_all[[ 'SCam3_Gauss_xrms', 'SCam3_Gauss_yrms', 'SCam3_Gauss_urms', 'SCam3_Gauss_vrms']]

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(14,8)})

ax = sns.lineplot(data=df_cam_ctr[:10000], palette='viridis', legend='full', lw=3)

plt.legend(bbox_to_anchor=(1, 1))
plt.ylabel('Centroid Location)')
plt.xlabel('Observation Step (Injected Anomaly Excluded)')
plt.show()

# %%
# Out:
#    SCam3_Gauss_xCentroid SCam3_tt  SCam3_Gauss_yCentroid  \
# 0             146.734455    69928              68.852859
# 1             155.273385    69929              71.485349
# 2             155.639160    69930              66.917990
# 3             139.119013    69931              66.345845
# 4             161.013466    69932              74.411032
#
#    SCam3_Gauss_uCentroid  SCam3_Gauss_vCentroid
# 0             375.222468             426.628428
# 1             383.426830             422.756037
# 2             380.102540             418.882018
# 3             368.181755             429.979276
# 4             389.240224             420.522658
# /var/folders/9y/xybzdfbx2qg8q2t6qlj43z7c0000gn/T/ipykernel_24592/3308123064.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(14,8)})

ax = sns.lineplot(data=df_cam_var[:10000], palette='magma', legend='full', lw=3)

plt.legend(bbox_to_anchor=(1, 1))
plt.title("")
plt.ylabel('Variance (Fitted Gaussian)')
plt.xlabel('Observation Step (Injected Anomaly Excluded)')
plt.show()

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(14,8)})

ax = sns.lineplot(data=df_cam_ctr[:10000], palette='viridis', legend='full', lw=3)

plt.legend(bbox_to_anchor=(1, 1))
plt.ylabel('Centroid Location)')
plt.xlabel('Observation Step (Injected Anomaly Excluded)')
plt.show()

# %%
lcam_cols = ['LCamGauss_xCentroid',
       'LCamGauss_xrms', 'LCamGauss_yCentroid', 'LCamGauss_yrms',
       'LCamGauss_uCentroid', 'LCamGauss_urms', 'LCamGauss_vCentroid',
       'LCamGauss_vrms', 'LCamGauss_Gaussian_Sum']

lcam_ctr = df_all[['LCamGauss_xCentroid',  'LCamGauss_yCentroid','LCamGauss_uCentroid','LCamGauss_vCentroid']]

lcam_var = df_all[[ 'LCamGauss_xrms', 'LCamGauss_yrms', 'LCamGauss_urms', 'LCamGauss_vrms']]

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(14,8)})

ax = sns.lineplot(data=lcam_ctr[:10000], palette='magma', legend='full', lw=3)

plt.legend(bbox_to_anchor=(1, 1))
plt.title("LCam Data (Earlier Camera Sensor)")
plt.ylabel('Centroid Location)')
plt.xlabel('Observation Step (Injected Anomaly Excluded)')
plt.show()

# %%
sns.set_style('darkgrid')
sns.set(rc={'figure.figsize':(14,8)})

ax = sns.lineplot(data=lcam_var[:10000], palette='magma', legend='full', lw=3)

plt.legend(bbox_to_anchor=(1, 1))
plt.title("LCam Data (Earlier Camera Sensor)")
plt.ylabel('Variance (Fitted Gaussian)')
plt.xlabel('Observation Step (Injected Anomaly Excluded)')
plt.show()
